# %%
G = SymmetricGroup(4)
X = Graph(G.cayley_graph(generators=G.conjugacy_class([4]).list()))
Y = Graph(G.cayley_graph(generators=G.conjugacy_class([2,1,1]).list()))
T = (graphs.PathGraph(3)).cartesian_product(graphs.PathGraph(2))
Z = X.subgraph_search(T,induced=True)
X.show()
# Out:
# Graphics object consisting of 97 graphics primitives
